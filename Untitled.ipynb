# %%
import json
import pandas as pd
import matplotlib.pyplot as plt


#color styles
highColor = "#C780FA"
lowColor = "#FF7B54"

# %%
#load data
file = "all-in_podcast.json"
data = None
with open(file, 'r') as f:
    data = json.load(f)

channel_id, stats = data.popitem()
print(channel_id)
channel_stats = stats["channel_statistics"]
video_stats = stats["video_data"]
# Out:
# UCESLZhusAkFfsNsApnjF_Cg

# %% [markdown]
# # Channel Statistics

# %%
#Channel Statistics
total_views = int(channel_stats["viewCount"])
total_subscribers = int(channel_stats["subscriberCount"])
total_videos = int(channel_stats["videoCount"])
print("\nSummary Stats\n")
print(f"Total Views: {total_views:,} \nTotal Subs: {total_subscribers:,} \nTotal Videos: {total_videos:,}")
print(f"Total Channel Likes: {df['likes'].sum():,}")
print(f"Total Channel Comments: {df['comments'].sum():,}")
print(f"\nAverage Summary\n")
avg_views = round(df['views'].mean(),2)
avg_likes = round(df['likes'].mean(),2)
avg_comments = round(df['comments'].mean(),2)
print(f"Average Views per video: {avg_views:,}")
print(f"Average Likes per video: {avg_likes:,}")
print(f"Average Comments per video: {avg_comments:,}")
# Out:
# Summary Stats
#
# Total Views: 22,277,726
# Total Subs: 298,000
# Total Videos: 132
# Total Channel Likes: 554,978
# Total Channel Comments: 121,920
#
# Average Summary
#
# Average Views per video: 169,739.97
# Average Likes per video: 4,236.47
# Average Comments per video: 930.69

# %%
#Video statistics, sort videos by views
sorted_vids = sorted(video_stats.items(), key=lambda item: int(item[1]["viewCount"]), reverse=True)

# %%
stats = []
for vid in sorted_vids:
    video_id = vid[0]
    title = vid[1]["title"]
    views = int(vid[1]["viewCount"])
    likes = int(vid[1]["likeCount"])
    comments = int(vid[1]["commentCount"])
    stats.append([title,views,likes,comments])

# %%
#create dataframe

df = pd.DataFrame(stats, columns=["title", "views", "likes", "comments"])
df
# Out:
#                                                  title    views  likes  \
# 0    E69: Elon Musk on Twitter's bot problem, Space...  2297902  55466
# 1        E109: 2022 Bestie Awards Live from Twitter HQ   413627  10009
# 2    E105: Tech culture wars: Elon vs. SBF, Sabotag...   385548   8844
# 3    E19: Robinhood's GameStop decision: Why did it...   384055  13575
# 4    E106: SBF's media strategy, FTX culpability, C...   377767   9104
# ..                                                 ...      ...    ...
# 126  David Friedberg on leaders vs. managers & the ...    17564    797
# 127  David Friedberg on the rise & risk of decentra...    16627    547
# 128  David Friedberg's COVID-19 vaccine rollout str...    13653    375
# 129  David Sacks on WallStreetBets as Parler 2.0 & ...    12654    458
# 130  David Sacks on the need to end hyperpartisansh...     9544    227
#
#      comments
# 0        6769
# 1        1807
# 2        2152
# 3        2681
# 4        2346
# ..        ...
# 126        52
# 127        45
# 128        56
# 129        56
# 130        73
#
# [131 rows x 4 columns]

# %% [markdown]
# # Top 10 Video with most Views

# %%
top10 = df.head(10).sort_values(by="views", ascending=True)

fig = plt.figure(figsize=(15, 8))
 
# creating the bar plot
plt.ticklabel_format(style='plain')
plt.barh(top10["title"], top10["views"], color=highColor)


plt.xlabel("Total Views")
plt.ylabel("Video Title")
plt.title("Top 10 Videos")
plt.show()

# %% [markdown]
# # Top 10 videos with least views

# %%
bottom10 = df.tail(10).sort_values(by='views', ascending=True)
fig = plt.figure(figsize=(15, 8))
 
# creating the bar plot
plt.ticklabel_format(style='plain')
plt.barh(bottom10["title"], bottom10["views"], color=lowColor)


plt.xlabel("Total Views")
plt.ylabel("Video Title")
plt.title("Least Popular 10 Videos")
plt.show()

# %%
#Likes vs Dislikes
likes_avg = top10['likes'].mean()
comments_avg = top10['comments'].mean()

print("Average Likes and Comments Top 10 Videos\n")
print(f"Average Likes: {likes_avg:,} \nAverage Comments: {comments_avg:,}")
# Out:
# Average Likes and Comments Top 10 Videos
#
# Average Likes: 13,411.9
# Average Comments: 2,386.8

# %%
#Likes vs Dislikes For Least Viewed Videos
likes_avg = bottom10['likes'].mean()
comments_avg = bottom10['comments'].mean()

print("Average Likes and Comments Least Viewed 10 Videos\n")
print(f"Average Likes: {likes_avg:,} \nAverage Comments: {comments_avg:,}")
# Out:
# Average Likes and Comments Least Viewed 10 Videos
#
# Average Likes: 614.4
# Average Comments: 104.4

# %% [markdown]
# # Top 10 Videos with most Comments

# %%
top10_comments = df.head(10).sort_values(by="comments", ascending=True)
# creating the bar plot
fig = plt.figure(figsize=(15, 8))
plt.ticklabel_format(style='plain')
plt.barh(top10_comments["title"], top10_comments["comments"], color=highColor)


plt.xlabel("Total Comments")
plt.ylabel("Video Title")
plt.title("Top 10 Videos with most comments")
plt.show()

# %% [markdown]
# # Top 10 Videos with the Least Comments

# %%
bottom10_least_comments = df.tail(10).sort_values(by="comments", ascending=True)
# creating the bar plot
fig = plt.figure(figsize=(15, 8))
plt.ticklabel_format(style='plain')
plt.barh(bottom10_least_comments["title"], bottom10_least_comments["comments"], color=lowColor)


plt.xlabel("Total Comments")
plt.ylabel("Video Title")
plt.title("Top 10 Videos with least comments")
plt.show()

# %% [markdown]
# # Top 10 Videos with the most Likes

# %%
top10_likes = df.head(10).sort_values(by="likes", ascending=True)
# creating the bar plot
fig = plt.figure(figsize=(15, 8))
plt.ticklabel_format(style='plain')
plt.barh(top10_likes["title"], top10_likes["likes"], color=highColor)


plt.xlabel("Total Likes")
plt.ylabel("Video Title")
plt.title("Top 10 Videos with least likes")
plt.show()

# %% [markdown]
# # Top 10 Videos with the least Likes

# %%
top10_least_likes = df.tail(10).sort_values(by="likes", ascending=True)
# creating the bar plot
fig = plt.figure(figsize=(15, 8))
plt.ticklabel_format(style='plain')
plt.barh(top10_least_likes["title"], top10_least_likes["likes"], color=lowColor)


plt.xlabel("Total Likes")
plt.ylabel("Video Title")
plt.title("Top 10 Videos with least likes")
plt.show()
